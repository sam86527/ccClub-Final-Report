# %%
from linebot.models import (MessageEvent, TemplateSendMessage , PostbackEvent)

#引入按鍵模板
from linebot.models.template import(ButtonsTemplate)

# 引用Web Server套件
from flask import Flask, request, abort

# 從linebot 套件包裡引用 LineBotApi 與 WebhookHandler 類別
from linebot import (LineBotApi, WebhookHandler)

# 引用無效簽章錯誤
from linebot.exceptions import (InvalidSignatureError)

# 載入json處理套件
import json

# 載入基礎設定檔
secretFileContentJson=json.load(open('line_secret_key_bf', 'r', encoding='utf-8'))
server_url=secretFileContentJson.get("server_url")

# 設定Server啟用細節
app = Flask(__name__)

# 生成實體物件
line_bot_api = LineBotApi(secretFileContentJson.get("channel_access_token"))
handler = WebhookHandler(secretFileContentJson.get("secret_key"))

# 啟動server對外接口，使Line能丟消息進來
@app.route("/", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        abort(400)

    return 'OK'

# %%
# 將消息模型，文字收取消息與文字寄發消息 引入
from linebot.models import (
    MessageEvent, TextMessage, 
    TextSendMessage, ImageSendMessage, StickerSendMessage)

# 消息清單
reply_message_list = [
    # text 'send' message
TextSendMessage(text="寶貝，我好想你。") ]

# %%
# FollowEvent:是家好友之後的第一個互動

from linebot.models.events import (FollowEvent)

# 載入requests套件
import requests


# 告知handler，如果收到FollowEvent，則做下面的方法處理
@handler.add(FollowEvent)
def reply_text_and_get_user_profile(event):
    
    # 取出消息內User的資料
    # 取個資
    user_profile = line_bot_api.get_profile(event.source.user_id)
    print(user_profile.user_id)
        
     # 將用戶資訊存在檔案內
    with open("users.txt", "a") as myfile:
        myfile.write(json.dumps(vars(user_profile),sort_keys=True))
        myfile.write('\r\n')
        
    global comapare_channel
    compare_channel = False
        
    # 將菜單綁定在用戶身上
    # linkRichMenuId=secretFileContentJson.get("rich_menu_id")
    # linkResult=line_bot_api.link_rich_menu_to_user(user_profile.user_id, linkRichMenuId)
    
    # 回覆文字消息與圖片消息
    line_bot_api.reply_message(
        event.reply_token,
        reply_message_list
    )

# %%
# FollowEvent:是家好友之後的第一個互動

from linebot.models.events import (FollowEvent)

# 載入requests套件
import requests


# 告知handler，如果收到FollowEvent，則做下面的方法處理
@handler.add(FollowEvent)
def reply_text_and_get_user_profile(event):
    
    # 取出消息內User的資料
    # 取個資
    user_profile = line_bot_api.get_profile(event.source.user_id)
    print(user_profile.user_id)
        
     # 將用戶資訊存在檔案內
    with open("users.txt", "a") as myfile:
        myfile.write(json.dumps(vars(user_profile),sort_keys=True))
        myfile.write('\r\n')
        
    global comapare_channel
    compare_channel = False
        
    # 將菜單綁定在用戶身上
    # linkRichMenuId=secretFileContentJson.get("rich_menu_id")
    # linkResult=line_bot_api.link_rich_menu_to_user(user_profile.user_id, linkRichMenuId)
    
    # 回覆文字消息與圖片消息
    line_bot_api.reply_message(
        event.reply_token,
        reply_message_list
    )

# %%
import random

love_talk = ['海會枯 石會爛 我的伴侶隨時換', '美人虐我千百遍 我待每人如初戀', '你是初戀 其他人都是排練', '你說你喜歡海 所以我一直浪', '今晚我為你淫蕩 明早將我遺忘', '女人如衣服 不換不舒服', '哥哥不好色 好什麼? How are you嗎?', '愛你只是開玩笑 只想和你睡覺覺', '我是數 你是三角 因為三角函數', '你也許不在我的心上 但可以在我的身上', '我不是渣 只是心懷天下 想給每個女孩一個家', '妹子的青春有限 青春的妹子無限', '拜託你不要讓我太累 晚上還要應付你姊妹', '喜歡一個人太累了 所以我要喜歡十個', '我只能中午跟你見面 不然早晚會愛上你', '不能共處一世 但可以共處一室', '先打好關係 之後才能隨便發生關係', '掏心掏肺 不如我們回家QK', '兩天朋友三天妹 七天就是小寶貝']

# %%
food_lst = ['yupoke', '站食可以', '12mini', '力量拉麵', '四海遊龍', '順園小館', '季丼屋', 'DGI', '摩斯漢堡', '麥當勞', 'SUBWAY', '秀食屋', '7-11', '烤肉飯', '沙爹士多', '源士林', '肯德基', '韓天閣', 'sukiya', '吉野家']

# %%
drink_lst = ['50嵐','茶攤會','可不可', '清心', '清水茶香', '梧桐號']

# %%
joke_lst = ["https://i.imgur.com//e8uRUyt.jpg", "https://i.imgur.com//35Z013x.jpg", "https://encrypted-tbn0.gstatic.com//images?q=tbn:ANd9GcRfGfiWRQiaXXi1U8TsbvDyr8R1Psd5UWNB8Q&usqp=CAU", "https://i.imgur.com//06L5T4F.jpg", "https://fun-tainan.banner.tw//taiwancool//files//tdcPost//a85e93f10c97f722ad06626e39bbc29d.jpg", "https://i.imgur.com//bmk0ViZ.jpg", "https://i0.wp.com//img.iqmore.com//iqmoreidv_img//news//2020//others//2020_captain_america_elevator_meme//12.JPG?w=810&ssl=1", "https://i.imgur.com//aHOB8hF.jpg", "https://i.imgur.com//YexltIa.jpg"]

# %%
# 這裡是互動式的

@handler.add(MessageEvent, message=TextMessage)
def handle_message(event):
    if '帥' in event.message.text:
        reply_message = TextSendMessage(text="怎麼配得上寶貝")
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '⋯' in event.message.text:
        reply_message = TextSendMessage(text="寶貝幹嘛吞吞吐吐的 這種事晚上再來")
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '.' in event.message.text:
        reply_message = TextSendMessage(text="寶貝幹嘛吞吞吐吐的 這種事晚上再來")
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '小' in event.message.text:
        reply_message = TextSendMessage(text="我哪裡小了!")
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '謝謝' in event.message.text:
        reply_message = TextSendMessage(text="不客氣寶貝")
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '幹' in event.message.text:
        reply_message = TextSendMessage(text="好啊!")
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '乾' in event.message.text:
        reply_message = TextSendMessage(text="寶貝連罵髒話都好可愛")
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif "不愛" in event.message.text:
        reply_message = StickerSendMessage(package_id=1, sticker_id=3)
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '愛' in event.message.text:
        reply_message = TextSendMessage(text="我愛你是肯定的 只愛你是不可能的")
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '閉嘴' in event.message.text:
        reply_message = TextSendMessage(text="寶貝不要生氣嘛 我帶你去吃飯飯")
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '分手' in event.message.text:
        reply_message = StickerSendMessage(package_id=1, sticker_id=9)
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '彥棋' in event.message.text:
        reply_message = TextSendMessage(text="他很帥呢")
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '貓' in event.message.text:
        reply_message = TextSendMessage(text="要不要來我家看貓 我家的貓會後空翻")
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '吃' in event.message.text:
        reply_message = TextSendMessage(text="寶貝要不要吃" + random.choice(food_lst))
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '喝' in event.message.text:
        reply_message = TextSendMessage(text="寶貝喝" + random.choice(drink_lst) + "好不好")
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '不好' in event.message.text:
        reply_message = TextSendMessage(text="那寶貝喝" + random.choice(drink_lst) + "好不好")
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '不要' in event.message.text:
        reply_message = TextSendMessage(text="那寶貝要不要吃" + random.choice(food_lst))
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif "逗我笑" in event.message.text:
        url = random.choice(joke_lst)
        reply_message = ImageSendMessage(original_content_url=url, preview_image_url=url)
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif "好" in event.message.text:
        reply_message = StickerSendMessage(package_id=1, sticker_id=2)
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif "帥" in event.message.text:
        reply_message = StickerSendMessage(package_id=1, sticker_id=5)
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif "哈" in event.message.text:
        reply_message = StickerSendMessage(package_id=1, sticker_id=106)
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif "嘻" in event.message.text:
        reply_message = StickerSendMessage(package_id=1, sticker_id=10)
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '吼' in event.message.text:
        reply_message = TextSendMessage(text="寶貝對不起!寶貝別生氣!")
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '洗澡' in event.message.text:
        reply_message = TextSendMessage(text="天涯何處無芳草 我要陪你去洗澡")
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '晚安' in event.message.text:
        reply_message = TextSendMessage(text="給我去睡覺!")
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '早安' in event.message.text:
        reply_message = ImageSendMessage(original_content_url='https://pbs.twimg.com//media//D4sDKz-UIAEMJbZ.png', preview_image_url='https://pbs.twimg.com//media//D4sDKz-UIAEMJbZ.png')
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    elif '爛' in event.message.text:
        reply_message = ImageSendMessage(original_content_url='https://cf.shopee.tw//file//b9e8b99589a91e9efcb28ed217ab7164', preview_image_url='https://cf.shopee.tw//file//b9e8b99589a91e9efcb28ed217ab7164')
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)
    else:
        reply_message = TextSendMessage(text=random.choice(love_talk))
        line_bot_api.reply_message(
        event.reply_token,
        reply_message)

# %%
@handler.add(PostbackEvent)
def handle_post_message(event):
    print(event.postback.data)
    
    result_message_array =[]
    replyJsonPath = 'reply.json'
    result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
    
    line_bot_api.reply_message(
            event.reply_token,
            result_message_array)

# %%
if __name__ == "__main__":
    app.run(host='0.0.0.0')
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [28/Dec/2020 19:05:32] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Dec/2020 19:05:46] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Dec/2020 19:06:06] "POST / HTTP/1.1" 200 -

# %%
import datetime
import time

def doSth():
    line_bot_api.push_message('U8a1f14bb1ac125ff933bd39c3ccc9d01', TextSendMessage(text='寶貝聖誕節快樂'))
    # 假裝做這件事情需要一分鐘
    time.sleep(60)

def main(h=0, m=0):
    # h表示設定的小時，m為設定的分鐘
    while True:
        # 判斷是否達到設定時間，例如0:00
        while True:
            now = datetime.datetime.now()
            # 到達設定時間，結束內循環
            if now.hour == h and now.minute == m:
                break
            # 不到時間就等20秒之後再次檢測
            time.sleep(20)
        # 做正事，一天做一次
        doSth()

main(23,30)

# %%
import datetime
now = datetime.datetime.now()

print(now.minute)
# Out:
# 19

# %%
line_bot_api.push_message(,TextSendMessage(text='宛柔你好呀'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-258dde4c8c0e> in <module>
# ----> 1 line_bot_api.push_message(TextSendMessage(text='宛柔你好呀'))
#
# TypeError: push_message() missing 1 required positional argument: 'messages'

# %%
import datetime

datetime.datetime.now()

if datetime.date.today() == "2020-12-23":
    line_bot_api.push_message(TextSendMessage(text='Hello World!'))

# %%
elif event.message.text == "貼圖":
        line_bot_api.reply_message(event.reply_token,StickerSendMessage(package_id=1, sticker_id=2))

# %%
elif event.message.text == "圖片":
    line_bot_api.reply_message(event.reply_token,ImageSendMessage(original_content_url=https://i.imgur.com//35Z013x.jpg',
    preview_image_url='https://i.imgur.com//35Z013x.jpg'))
